# %%
import pandas as pd
import csv 
import os

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("Income_Age_Data.csv", sep="\t", error_bad_lines=False)
df = pd.DataFrame(data)

# %%
df
# Out:
#                     County  Under 25 Years  25 to 44 Years  45 to 64 Years  \
# 0           Alameda County         42139.0        104385.0        107034.0
# 1            Alpine County             0.0         93750.0             0.0
# 2            Amador County             0.0         64191.0         71581.0
# 3             Butte County         23845.0         54725.0         61169.0
# 4         Calaveras County         49459.0         55221.0         78556.0
# 5            Colusa County         26429.0         60503.0         68010.0
# 6      Contra Costa County         44084.0         96817.0        111083.0
# 7         Del Norte County         22745.0         53118.0         44753.0
# 8         El Dorado County         40559.0         83829.0        101742.0
# 9            Fresno County         26480.0         51218.0         62474.0
# 10            Glenn County         18125.0         50731.0         53561.0
# ...

# %%
df["Under 25 Years"] = df["Under 25 Years"].replace(["\$", ","], "", regex=True).astype(float)
df["25 to 44 Years"] = df["25 to 44 Years"].replace(["\$", ","], "", regex=True).astype(float)
df["45 to 64 Years"] = df["45 to 64 Years"].replace(["\$", ","], "", regex=True).astype(float)
df["65 Years and Over"] = df["65 Years and Over"].replace(["\$", ","], "", regex=True).astype(float)

df.head()
# Out:
#              County  Under 25 Years  25 to 44 Years  45 to 64 Years  \
# 0    Alameda County         42139.0        104385.0        107034.0
# 1     Alpine County             0.0         93750.0             0.0
# 2     Amador County             0.0         64191.0         71581.0
# 3      Butte County         23845.0         54725.0         61169.0
# 4  Calaveras County         49459.0         55221.0         78556.0
#
#    65 Years and Over
# 0            58065.0
# 1            68500.0
# 2            48977.0
# 3            40679.0
# 4            49260.0

# %%
df.dtypes
# Out:
# County                object
# Under 25 Years       float64
# 25 to 44 Years       float64
# 45 to 64 Years       float64
# 65 Years and Over    float64
# dtype: object

# %%
df_2 = df[["25 to 44 Years", "Under 25 Years"]]
df_3 = df[["25 to 44 Years", "45 to 64 Years"]]
df_4 = df[["25 to 44 Years", "65 Years and Over"]]

# %%
df_2.plot()
df_3.plot()
df_4.plot()
plt.show()

# %%
total_Under_25_Years = df["Under 25 Years"].sum()
total_25_to_44_Years = df["25 to 44 Years"].sum()
total_45_to_64_Years = df["45 to 64 Years"].sum()
total_65_Years_and_Over = df["65 Years and Over"].sum()

# %%
# Labels for the sections of our pie chart
labels = ["Under 25 Years", "25 to 44 Years", "45 to 64 Years", "65 Years and Over"]

# The values of each section of the pie chart
sizes = [total_Under_25_Years, total_25_to_44_Years, total_45_to_64_Years, total_65_Years_and_Over]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0, 0, 0.1, 0)

# %%
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.axis("equal")
# Save an image of our chart and print the final product to the screen

plt.show()
